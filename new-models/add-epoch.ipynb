# %%
from ultralytics import YOLO

# %%
model = YOLO("runs/detect/20-epochs/weights/last.pt")

# %%
model.train(
    data="data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    device=0,
    name="extended-epochs"
)
