# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s.pt")

model.train(
    data="data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    device=0,
    name="20-epochs",
)

# %%
model.val()
