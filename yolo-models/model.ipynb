# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8s.pt")

model.train(
    data="data.yaml",
    epochs=75,
    imgsz=640,
    batch=16,
    device=0,
    name="s-models",
)
# Out:
# New https://pypi.org/project/ultralytics/8.3.251 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.249  Python-3.12.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# ...

# %%
model.val()
# Out:
# Ultralytics 8.3.249  Python-3.12.0 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 4050 Laptop GPU, 6140MiB)
# Model summary (fused): 72 layers, 11,129,067 parameters, 0 gradients, 28.5 GFLOPs
# val: Fast image access  (ping: 0.10.0 ms, read: 710.5777.6 MB/s, size: 154.9 KB)
# val: Scanning D:\wildlife-monitoring\yolo-models\animal_dataset\labels\val.cache... 948 images, 15 backgrounds, 4 corrupt: 100% ━━━━━━━━━━━━ 948/948 944.7Kit/s 0.0s
# val: D:\wildlife-monitoring\yolo-models\animal_dataset\images\val\bision_5VYW5X8NUGUB_jpg.rf.9954b98d222064c167cb75a8ff50b331.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.3754764 1.4516006]
# val: D:\wildlife-monitoring\yolo-models\animal_dataset\images\val\bision_HFXI3SHKPZM2_jpg.rf.3c3968599ba0194e0adbd2f130f5e824.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [1.075362]
# ...
